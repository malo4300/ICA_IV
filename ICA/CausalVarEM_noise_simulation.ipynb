# %%
from models.ICA_EM import *
from models.dgp import *
from models.metrics import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n = 10000
J = 6
I = 5

# %%
def norm_funtion(A):
    # [0,0], [1,1] must be one
    A_0 = A[:, 0]/A[0,0]
    return A_0

# %%
B = 50
noise_grid = np.linspace(0, 3, 10)
treatments_true = np.zeros((len(noise_grid), B))
treatments_pred = np.zeros((len(noise_grid), B))
ll_score = np.zeros((len(noise_grid), B))
mse_score = np.zeros((len(noise_grid), B))
fscore = np.zeros((len(noise_grid), B))

# %%
for i in tqdm.tqdm(range(len(noise_grid))):
    data = dgp(noise_dict= {"loc" : 0, "scale" : noise_grid[i]}, prior= {"loc" : 0, "scale" : 1/np.sqrt(2)})
    for j in range(B):
        data.generate_data(n, I, J, random_state=j)
        est = CausalVarEM(update_sigma=False, true_A= data.mixing_matrix_observed, mode = "each", random_seed = j)
        est.fit(data.data_observed, J, noise_params={"mean": 0, "std": noise_grid[i] if noise_grid[i] > 0 else 1}, progress_bar=False)
        treatments_true[i, j] = data.treatment_effect
        best_perm, score = f_score(data.mixing_matrix_observed, est.A)
        sorted_A = est.A[:, best_perm]
        treatments_pred[i, j] = norm_funtion(sorted_A)[1]
        ll_score[i, j] = likelihood_score(data.signals, est.Signals, true_paras={"mean": 0, "scale": 1/np.sqrt(2)})
        mse_score[i, j] = mean_squared_error(data.signals, est.Signals)
        fscore[i, j] = score
# Out:
#   0%|          | 0/10 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 6
#       4 data.generate_data(n, I, J, random_state=j)
#       5 est = CausalVarEM(update_sigma=False, true_A= data.mixing_matrix_observed, mode = "each", random_seed = j)
# ----> 6 est.fit(data.data_observed, J, noise_params={"mean": 0, "std": noise_grid[i] if noise_grid[i] > 0 else 1}, progress_bar=False)
#       7 treatments_true[i, j] = data.treatment_effect
#       8 best_perm, score = f_score(data.mixing_matrix_observed, est.A)
#
# File ~/Documents/coding/eth/semester_project/models/ICA_EM.py:114, in VarEM.fit(self, X, J, noise_params, progress_bar)
#     112     progress_bar_iter = range(self.max_iter)
#     113 for i in progress_bar_iter:
# --> 114     diff = self.update_A()
#     115     if diff < self.tol:
#     116         print(f"Converged after {i} iterations with diff = {diff:.4f}")
#
# File ~/Documents/coding/eth/semester_project/models/ICA_EM.py:203, in CausalVarEM.update_A(self)
#     201     x_outer = np.outer(self.X[i,:], self.X[i,:])
#     202     temp1 += x_outer @ M_i.T @ self.A @ omega_i
# --> 203     temp2 += omega_i @ (np.eye(self.J) - self.A.T @ M_i @ (np.eye(self.I) - x_outer @ M_i.T) @ self.A @ omega_i)
#     204     self._update_xi(i, M_i, omega_i, x_outer)
#     205 A_new = temp1 @ np.linalg.inv(temp2)
#
# File ~/micromamba/envs/sem_pj/lib/python3.12/site-packages/numpy/lib/_twodim_base_impl.py:163, in eye(N, M, k, dtype, order, device, like)
#     159         raise ValueError("Input must be >= 1-d.")
#     160     return m[::-1, ...]
# --> 163 @set_array_function_like_doc
#     164 @set_module('numpy')
#     165 def eye(N, M=None, k=0, dtype=float, order='C', *, device=None, like=None):
#     166     """
#     167     Return a 2-D array with ones on the diagonal and zeros elsewhere.
#     168
#    (...)
#     216
#     217     """
#     218     if like is not None:
#
# KeyboardInterrupt:

# %%
# save the results
#for i in range(len(noise_grid)):
#    df = pd.DataFrame({"treatments_true": treatments_true[i], "treatments_pred": treatments_pred[i], "ll_score": ll_score[i], "mse_score": mse_score[i], "fscore": fscore[i]})
#    df.to_csv(f"results/increase_noise/CausalVarEM_{noise_grid[i]}.csv", index=False)

# %%
# load the results 
for i in range(len(noise_grid)):
    df = pd.read_csv(f"results/increase_noise/CausalVarEM_{noise_grid[i]}.csv")
    treatments_true[i] = df["treatments_true"].values
    treatments_pred[i] = df["treatments_pred"].values
    ll_score[i] = df["ll_score"].values
    mse_score[i] = df["mse_score"].values
    fscore[i] = df["fscore"].values

# %%
treatment_diff = (treatments_true - treatments_pred)
treatment_mse = np.mean(np.abs(treatment_diff), axis=1)
sns.scatterplot(x=noise_grid, y=treatment_mse)
# Out:
# <Axes: >

# %%
ll_score_mean = np.mean(ll_score, axis=1)
sns.scatterplot(x=noise_grid, y=ll_score_mean)
# Out:
# <Axes: >

# %%
mse_score_mean = np.mean(mse_score, axis=1)
sns.scatterplot(x=noise_grid, y=mse_score_mean)
# Out:
# <Axes: >

# %%
fscore_mean = np.mean(fscore, axis=1)
sns.scatterplot(x=noise_grid, y=fscore_mean)
# Out:
# <Axes: >

# %%
# plot all in one
fig, ax = plt.subplots(2, 2, figsize=(15
                                , 10))
                            
                            
sns.scatterplot(x=noise_grid, y=treatment_mse, ax=ax[0, 0])
ax[0, 0].set_title("Treatment MSE")
sns.scatterplot(x=noise_grid, y=ll_score_mean, ax=ax[0, 1])
ax[0, 1].set_title("LL Score")
sns.scatterplot(x=noise_grid, y=mse_score_mean, ax=ax[1, 0])
ax[1, 0].set_title("MSE Score")
sns.scatterplot(x=noise_grid, y=fscore_mean, ax=ax[1, 1])
ax[1, 1].set_title("F Score")
# Out:
# Text(0.5, 1.0, 'F Score')
